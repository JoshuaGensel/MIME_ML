# %%
#load dmMIMESim data
from simDataPreprocessing import convertToOneHotMatrix

bound_1_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot1/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=1, seed=2536)
bound_1_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot6/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=6, seed=5675)
bound_1_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot15/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=15, seed=3456)
bound_1_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot30/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=30, seed=972358)

unbound_1_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot1/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=1, seed=867532)
unbound_1_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot6/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=6, seed=10357)
unbound_1_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot15/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=15, seed=67238)
unbound_1_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot30/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=1, proteinConcentration2=30, seed=564123)
print('first round prot1 done')
bound_6_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot1/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=1, seed=4527)
bound_6_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot6/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=6, seed=24577)
bound_6_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot15/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=15, seed=23456)
bound_6_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot30/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=30, seed=75948)

unbound_6_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot1/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=1, seed=2456)
unbound_6_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot6/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=6, seed=45678)
unbound_6_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot15/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=15, seed=3415)
unbound_6_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt6/prot30/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=6, proteinConcentration2=30, seed=7469)
print('first round prot6 done')
bound_15_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot1/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=1, seed=13465)
bound_15_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot6/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=6, seed=3658)
bound_15_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot15/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=15, seed=13456)
bound_15_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot30/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=30, seed=2457)

unbound_15_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot1/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=1, seed=83656)
unbound_15_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot6/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=6, seed=2574)
unbound_15_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot15/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=15, seed=4679)
unbound_15_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt15/prot30/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=15, proteinConcentration2=30, seed=1345)
print('first round prot15 done')
bound_30_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot1/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=1, seed=3567)
bound_30_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot6/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=6, seed=565674275)
bound_30_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot15/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=15, seed=2457)
bound_30_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot30/sequences/7.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=30, seed=25478)

unbound_30_1 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot1/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=1, seed=6583)
unbound_30_6 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot6/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=6, seed=4136)
unbound_30_15 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot15/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=15, seed=4356)
unbound_30_30 = convertToOneHotMatrix('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt30/prot30/sequences/8.txt',
                            maxNumSequences=10000, splittingProbability=3/100, readSize=23, proteinConcentration=30, proteinConcentration2=30, seed=564123)
print('done')
# Out:
# Running cells with '/bin/python3' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
#prepare data for training

import numpy as np
from sklearn.model_selection import train_test_split

#combine all bound and unbound data into one array
bound = np.concatenate((bound_1_1, bound_1_6, bound_1_15, bound_1_30, bound_6_1, bound_6_6, bound_6_15, bound_6_30, bound_15_1, bound_15_6, bound_15_15, bound_15_30, bound_30_1, bound_30_6, bound_30_15, bound_30_30), axis=0)
unbound = np.concatenate((unbound_1_1, unbound_1_6, unbound_1_15, unbound_1_30, unbound_6_1, unbound_6_6, unbound_6_15, unbound_6_30, unbound_15_1, unbound_15_6, unbound_15_15, unbound_15_30, unbound_30_1, unbound_30_6, unbound_30_15, unbound_30_30), axis=0)

#create labels for bound and unbound data
bound_labels = np.ones((bound.shape[0],1))
unbound_labels = np.zeros((unbound.shape[0],1))

#combine bound and unbound data and labels into one array
data = np.concatenate((bound, unbound), axis=0)
labels = np.concatenate((bound_labels, unbound_labels), axis=0)

#create training and test data
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((539788, 402), (231338, 402), (539788, 1), (231338, 1))

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression

#regularization parameter C
C = [0.01, 0.1, 1, 10]
#regularization parameter l1_ratio
l1_ratio = [0, 0.25, 0.5, 0.75, 1]

#train model for every combination of C and l1_ratio and evaluate correlation between weights and true kd values
for c in C:
    for l1 in l1_ratio:
        model = LogisticRegression(penalty='elasticnet', solver='saga', C=c, l1_ratio=l1)
        model.fit(X_train, y_train.ravel())   
        print("C: " + str(c) + " l1_ratio: " + str(l1) + " score: " + str(model.score(X_test, y_test).round(3)))
# Out:
# C: 0.001 l1_ratio: 0 score: 0.642
# C: 0.001 l1_ratio: 0.25 score: 0.637
# C: 0.001 l1_ratio: 0.5 score: 0.632
# C: 0.001 l1_ratio: 0.75 score: 0.629
# C: 0.001 l1_ratio: 1 score: 0.63
# C: 0.01 l1_ratio: 0 score: 0.647
# C: 0.01 l1_ratio: 0.25 score: 0.646
# C: 0.01 l1_ratio: 0.5 score: 0.646
# C: 0.01 l1_ratio: 0.75 score: 0.645
# C: 0.01 l1_ratio: 1 score: 0.643
# C: 0.1 l1_ratio: 0 score: 0.647
# C: 0.1 l1_ratio: 0.25 score: 0.648
# C: 0.1 l1_ratio: 0.5 score: 0.647
# C: 0.1 l1_ratio: 0.75 score: 0.647
# C: 0.1 l1_ratio: 1 score: 0.647
# C: 1 l1_ratio: 0 score: 0.648
# C: 1 l1_ratio: 0.25 score: 0.648
# C: 1 l1_ratio: 0.5 score: 0.648
# C: 1 l1_ratio: 0.75 score: 0.648
# C: 1 l1_ratio: 1 score: 0.648
# C: 10 l1_ratio: 0 score: 0.648
# C: 10 l1_ratio: 0.25 score: 0.648
# C: 10 l1_ratio: 0.5 score: 0.648
# C: 10 l1_ratio: 0.75 score: 0.648
# C: 10 l1_ratio: 1 score: 0.648
# C: 100 l1_ratio: 0 score: 0.648
# C: 100 l1_ratio: 0.25 score: 0.648
# C: 100 l1_ratio: 0.5 score: 0.648
# ...

# %%
# plot roc curve for model with C=0.1 and l1_ratio=0.5
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

model = LogisticRegression(penalty='elasticnet', solver='saga', C=0.1, l1_ratio=0.5)
model.fit(X_train, y_train.ravel())   
y_pred = model.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
#get kd values
kds = np.loadtxt('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/experimentalConditions/secondFromProt1/prot1/single_kds.txt')
kds[0:20]
# Out:
# array([0.212905, 0.362492, 1.      , 0.393369, 3.48016 , 1.      ,
#        1.      , 1.      , 1.      , 3.21897 , 0.416157, 0.547224,
#        1.      , 1.      , 1.      , 1.      , 0.44968 , 1.      ,
#        1.20477 , 3.24954 ])

# %%
#insert 1 at position 0 and then every 3rd position
kds = np.insert(kds, 0, 1)
kds = np.insert(kds, np.arange(4, len(kds), 3), 1)
kds[0:21]
# Out:
# array([1.      , 0.212905, 0.362492, 1.      , 1.      , 0.393369,
#        3.48016 , 1.      , 1.      , 1.      , 1.      , 1.      ,
#        1.      , 3.21897 , 0.416157, 0.547224, 1.      , 1.      ,
#        1.      , 1.      , 1.      ])

# %%
#get weights of model
weights = model.coef_[0][2:]
kds.shape, weights.shape
# Out:
# ((400,), (400,))

# %%
#line plot kd values
plt.plot(kds)
plt.show()

# %%
#line plot weights
plt.plot(weights)
plt.show()

# %%
#scatter plot kd values vs weights
plt.scatter(kds, weights)
plt.show()

# %%
#scatter plot log of kd values vs -1 * weights
from scipy.stats import pearsonr
corr, _ = pearsonr(np.log(kds), -1*weights)  
plt.scatter(np.log(kds), -1 * weights)
plt.xlabel('log(kd)')
plt.ylabel('weight')
plt.title(f'C=0.01, l1_ratio=0.25, corr={corr:.2f}')
plt.show()

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

#regularization parameter C
C = [0.01, 0.1, 1, 10]
#regularization parameter l1_ratio
l1_ratio = [0, 0.25, 0.5, 0.75, 1]

#train model for every combination of C and l1_ratio and evaluate correlation between weights and true kd values
for c in C:
    for l1 in l1_ratio:
        model = LogisticRegression(penalty='elasticnet', solver='saga', C=c, l1_ratio=l1)
        model.fit(X_train, y_train.ravel())
        #get model weights
        weights = model.coef_[0][2:]
        #correlation between weights and log of kd values
        corr, _ = pearsonr(np.log(kds), -1*weights)        
        print("C: " + str(c) + " l1_ratio: " + str(l1) + " corr: " + str(round(corr,3)) + " score: " + str(model.score(X_test, y_test).round(3)))
# Out:
# C: 0.01 l1_ratio: 0 corr: 0.903 score: 0.647
# C: 0.01 l1_ratio: 0.25 corr: 0.891 score: 0.646
# C: 0.01 l1_ratio: 0.5 corr: 0.865 score: 0.646
# C: 0.01 l1_ratio: 0.75 corr: 0.835 score: 0.645
# C: 0.01 l1_ratio: 1 corr: 0.796 score: 0.643
# C: 0.1 l1_ratio: 0 corr: 0.929 score: 0.647
# C: 0.1 l1_ratio: 0.25 corr: 0.929 score: 0.648
# C: 0.1 l1_ratio: 0.5 corr: 0.929 score: 0.647
# C: 0.1 l1_ratio: 0.75 corr: 0.929 score: 0.647
# C: 0.1 l1_ratio: 1 corr: 0.928 score: 0.647
# C: 1 l1_ratio: 0 corr: 0.932 score: 0.648
# C: 1 l1_ratio: 0.25 corr: 0.932 score: 0.648
# C: 1 l1_ratio: 0.5 corr: 0.932 score: 0.648
# C: 1 l1_ratio: 0.75 corr: 0.932 score: 0.648
# C: 1 l1_ratio: 1 corr: 0.932 score: 0.648
# C: 10 l1_ratio: 0 corr: 0.933 score: 0.648
# C: 10 l1_ratio: 0.25 corr: 0.933 score: 0.648
# C: 10 l1_ratio: 0.5 corr: 0.933 score: 0.648
# C: 10 l1_ratio: 0.75 corr: 0.933 score: 0.648
# C: 10 l1_ratio: 1 corr: 0.933 score: 0.648

# %%
#plot correlation between weights and log of kd values for model with C=10 and l1_ratio=0
model = LogisticRegression(penalty='l2', solver='saga', C=10)
model.fit(X_train, y_train.ravel())
weights = model.coef_[0][2:]
corr, _ = pearsonr(np.log(kds), -1*weights)        
plt.scatter(np.log(kds), -1 * weights)
plt.xlabel('log(kd)')
plt.ylabel('weight')
plt.title(f'C=10, l1_ratio=0, corr={corr:.2f}')
plt.show()

# %%
from simDataPreprocessing import loadSimDataOneHot

data, labels = loadSimDataOneHot('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/optimalConditions', maxNumSequences=10000, splittingProbability=3/100, readSize=23)
# Out:
# first round prot1 done
# first round prot6 done
# first round prot15 done
# first round prot 30 done

# %%
from sklearn.model_selection import train_test_split

#create training and test data
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((555211, 402), (237948, 402), (555211, 1), (237948, 1))

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import roc_auc_score

#regularization parameter C
C = [0.01, 0.1, 1, 10]

#train model for every C and evaluate roc_auc_score
for c in C:
    model = LogisticRegression(penalty='l2', solver='saga', C=c)
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict_proba(X_test)[:,1]
    print("C: " + str(c) + " roc_auc_score: " + str(roc_auc_score(y_test, y_pred).round(3)))
# Out:
# C: 0.01 roc_auc_score: 0.693
# C: 0.1 roc_auc_score: 0.694
# C: 1 roc_auc_score: 0.694
# C: 10 roc_auc_score: 0.694

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
#plot correlation between weights and log of kd values for model with C=10
kds = np.loadtxt('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/optimalConditions/secondFromProt1/prot1/single_kds.txt')
kds = np.insert(kds, 0, 1)
kds = np.insert(kds, np.arange(4, len(kds), 3), 1)

model = LogisticRegression(penalty='l2', solver='saga', C=10)
model.fit(X_train, y_train.ravel())
weights = model.coef_[0][2:]
corr, _ = pearsonr(np.log(kds), -1*weights)

plt.scatter(np.log(kds), -1 * weights)
plt.xlabel('log(kd)')
plt.ylabel('-weights')
plt.title(f'C=10, corr={corr:.2f}')
plt.show()

# %%
from simDataPreprocessing import loadSimDataOneHot

data, labels = loadSimDataOneHot('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/highError', maxNumSequences=10000, splittingProbability=3/100, readSize=23)
# Out:
# first round prot1 done
# first round prot6 done
# first round prot15 done
# first round prot 30 done

# %%
from sklearn.model_selection import train_test_split

#create training and test data
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((566125, 402), (242625, 402), (566125, 1), (242625, 1))

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import roc_auc_score

#regularization parameter C
C = [0.01, 0.1, 1, 10]

#train model for every C and evaluate roc_auc_score
for c in C:
    model = LogisticRegression(penalty='l2', solver='saga', C=c)
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict_proba(X_test)[:,1]
    print("C: " + str(c) + " roc_auc_score: " + str(roc_auc_score(y_test, y_pred).round(3)))
# Out:
# C: 0.01 roc_auc_score: 0.673
# C: 0.1 roc_auc_score: 0.673
# C: 1 roc_auc_score: 0.673
# C: 10 roc_auc_score: 0.673

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
#plot correlation between weights and log of kd values for model with C=10
kds = np.loadtxt('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/highError/secondFromProt1/prot1/single_kds.txt')
kds = np.insert(kds, 0, 1)
kds = np.insert(kds, np.arange(4, len(kds), 3), 1)

model = LogisticRegression(penalty='l2', solver='saga', C=10)
model.fit(X_train, y_train.ravel())
weights = model.coef_[0][2:]
corr, _ = pearsonr(np.log(kds), -1*weights)

plt.scatter(np.log(kds), -1 * weights)
plt.xlabel('log(kd)')
plt.ylabel('-weights')
plt.title(f'C=10, corr={corr:.2f}')
plt.show()

# %%
from simDataPreprocessing import loadSimDataOneHot

data, labels = loadSimDataOneHot('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/fullEffect', maxNumSequences=10000, splittingProbability=3/100, readSize=23)
# Out:
# first round prot1 done
# first round prot6 done
# first round prot15 done
# first round prot 30 done

# %%
from sklearn.model_selection import train_test_split

#create training and test data
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((635106, 402), (272189, 402), (635106, 1), (272189, 1))

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import roc_auc_score

#regularization parameter C
C = [0.01, 0.1, 1, 10]

#train model for every C and evaluate roc_auc_score
for c in C:
    model = LogisticRegression(penalty='l2', solver='saga', C=c)
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict_proba(X_test)[:,1]
    print("C: " + str(c) + " roc_auc_score: " + str(roc_auc_score(y_test, y_pred).round(3)))
# Out:
# C: 0.01 roc_auc_score: 0.657
# C: 0.1 roc_auc_score: 0.658
# C: 1 roc_auc_score: 0.658
# C: 10 roc_auc_score: 0.658

# %%
from simDataPreprocessing import loadSimDataOneHot

data, labels = loadSimDataOneHot('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/fullEpistasis', maxNumSequences=10000, splittingProbability=3/100, readSize=23)
# Out:
# first round prot1 done
# first round prot6 done
# first round prot15 done
# first round prot 30 done

# %%
from sklearn.model_selection import train_test_split

#create training and test data
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((740355, 402), (317295, 402), (740355, 1), (317295, 1))

# %%
#train logsitic regression model with different regularization parameters
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer
from sklearn.metrics import roc_auc_score

#regularization parameter C
C = [0.01, 0.1, 1, 10]

#train model for every C and evaluate roc_auc_score
for c in C:
    model = LogisticRegression(penalty='l2', solver='saga', C=c)
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict_proba(X_test)[:,1]
    print("C: " + str(c) + " roc_auc_score: " + str(roc_auc_score(y_test, y_pred).round(3)))
# Out:
# C: 0.01 roc_auc_score: 0.628
# C: 0.1 roc_auc_score: 0.629
# C: 1 roc_auc_score: 0.629
# C: 10 roc_auc_score: 0.629

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
#plot correlation between weights and log of kd values for model with C=10
kds = np.loadtxt('/mnt/d/data/MIME_data/simData/dmMIME/seqLen100/fullEpistasis/secondFromProt1/prot1/single_kds.txt')
kds = np.insert(kds, 0, 1)
kds = np.insert(kds, np.arange(4, len(kds), 3), 1)

model = LogisticRegression(penalty='l2', solver='saga', C=10)
model.fit(X_train, y_train.ravel())
weights = model.coef_[0][2:]
corr, _ = pearsonr(np.log(kds), -1*weights)

plt.scatter(np.log(kds), -1 * weights)
plt.xlabel('log(kd)')
plt.ylabel('-weights')
plt.title(f'C=10, corr={corr:.2f}')
plt.show()
