# %%
from testRegModel import testRegMod

# %%
#first testing as close to experimental conditions as possible
testRegMod(path='/mnt/d/data/MIME_data/data/simData/singleMIME/normalErrorTest', nSeq=5000)
# Out:
# Best cross-validation score: 0.54
# Best parameters:  {'C': 1, 'l1_ratio': 0.9}
# Test set score: 0.54
# <module 'matplotlib.pyplot' from '/home/jgen/miniconda3/envs/ds_base/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
#second testing with higher sequencing error (0.003)
testRegMod(path='/mnt/d/data/MIME_data/data/simData/singleMIME/highErrorTest', nSeq=5000)
# Out:
# Best cross-validation score: 0.54
# Best parameters:  {'C': 0.1, 'l1_ratio': 0.25}
# Test set score: 0.54
# <module 'matplotlib.pyplot' from '/home/jgen/miniconda3/envs/ds_base/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
#testing perfect scenario with no sequencing error and no epistasis
testRegMod(path='/mnt/d/data/MIME_data/data/simData/singleMIME/noEpistasisError', nSeq=5000)
# Out:
# Best cross-validation score: 0.53
# Best parameters:  {'C': 0.01, 'l1_ratio': 0.1}
# Test set score: 0.53
# <module 'matplotlib.pyplot' from '/home/jgen/miniconda3/envs/ds_base/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
testRegMod(path='/mnt/d/data/MIME_data/data/simData/singleMIME/noEpistasisError', nSeq=20000)
# Out:
# Best cross-validation score: 0.63
# Best parameters:  {'C': 1, 'l1_ratio': 0.75}
# Test set score: 0.63
# <module 'matplotlib.pyplot' from '/home/jgen/miniconda3/envs/ds_base/lib/python3.10/site-packages/matplotlib/pyplot.py'>
