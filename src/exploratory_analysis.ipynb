# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

# %%
# read in data

# define directory path
second_round_dir = '../data/experimental_data/all_pools_explo/'

# %%
# read in .txt files, values separated by whitespace
mpr_1_bound = np.loadtxt(first_round_dir + '1_mpr_bound.txt')
mpr_1_unbound = np.loadtxt(first_round_dir + '1_mpr_unbound.txt')
mpr_2_bound = np.loadtxt(first_round_dir + '2_mpr_bound.txt')
mpr_2_unbound = np.loadtxt(first_round_dir + '2_mpr_unbound.txt')
mpr_3_bound = np.loadtxt(first_round_dir + '3_mpr_bound.txt')
mpr_3_unbound = np.loadtxt(first_round_dir + '3_mpr_unbound.txt')

mprf_1_bound = np.loadtxt(first_round_dir + '1_mprf_bound.txt')
mprf_1_unbound = np.loadtxt(first_round_dir + '1_mprf_unbound.txt')
mprf_2_bound = np.loadtxt(first_round_dir + '2_mprf_bound.txt')
mprf_2_unbound = np.loadtxt(first_round_dir + '2_mprf_unbound.txt')
mprf_3_bound = np.loadtxt(first_round_dir + '3_mprf_bound.txt')
mprf_3_unbound = np.loadtxt(first_round_dir + '3_mprf_unbound.txt')

rl_1 = np.loadtxt(first_round_dir + '1_read_lengths.txt')
rl_2 = np.loadtxt(first_round_dir + '2_read_lengths.txt')
rl_3 = np.loadtxt(first_round_dir + '3_read_lengths.txt')

# %%
# print total number of reads per pool
print('Total number of reads per pool:')
print('Pool 1: ' + str(len(mpr_1_bound) + len(mpr_1_unbound)))
print('Pool 2: ' + str(len(mpr_2_bound) + len(mpr_2_unbound)))
print('Pool 3: ' + str(len(mpr_3_bound) + len(mpr_3_unbound)))

# print total number of reads per pool after filtering
print('Total number of reads per pool after filtering:')
print('Pool 1: ' + str(len(mprf_1_bound) + len(mprf_1_unbound)))
print('Pool 2: ' + str(len(mprf_2_bound) + len(mprf_2_unbound)))
print('Pool 3: ' + str(len(mprf_3_bound) + len(mprf_3_unbound)))
# Out:
# Total number of reads per pool:
# Pool 1: 7942404
# Pool 2: 7941720
# Pool 3: 7936947
# Total number of reads per pool after filtering:
# Pool 1: 2561971
# Pool 2: 2562264
# Pool 3: 2564049

# %%
# plot histograms of read lengths
# color the bins < 30 red
fig, ax = plt.subplots(2, 2, figsize=(8,8))
ax[0, 0].hist(rl_1, bins=100, color='blue')
ax[0, 0].set_title('Pool 1')
ax[0, 0].set_xlabel('Read Length')
ax[0, 0].set_ylabel('Count')
ax[0, 0].axvline(x=30, color='red')
ax[0, 1].hist(rl_2, bins=100, color='blue')
ax[0, 1].set_title('Pool 2')
ax[0, 1].set_xlabel('Read Length')
ax[0, 1].set_ylabel('Count')
ax[0, 1].axvline(x=30, color='red')
ax[1, 0].hist(rl_3, bins=100, color='blue')
ax[1, 0].set_title('Pool 3')
ax[1, 0].set_xlabel('Read Length')
ax[1, 0].set_ylabel('Count')
ax[1, 0].axvline(x=30, color='red')

plt.tight_layout()

# %%
# plot histograms of mutations per read bound vs unbound
fig, ax = plt.subplots(2, 2, figsize=(8,8))
ax[0, 0].hist(mpr_1_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[0, 0].hist(mpr_1_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[0, 0].set_title('Pool 1')
ax[0, 0].set_xlabel('Mutations per Read')
ax[0, 0].set_ylabel('Count')
ax[0, 0].legend()
ax[0, 1].hist(mpr_2_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[0, 1].hist(mpr_2_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[0, 1].set_title('Pool 2')
ax[0, 1].set_xlabel('Mutations per Read')
ax[0, 1].set_ylabel('Count')
ax[0, 1].legend()
ax[1, 0].hist(mpr_3_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[1, 0].hist(mpr_3_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[1, 0].set_title('Pool 3')
ax[1, 0].set_xlabel('Mutations per Read')
ax[1, 0].set_ylabel('Count')
ax[1, 0].legend()

plt.tight_layout()

# %%
# plot histograms of mutations per read bound vs unbound after filtering
fig, ax = plt.subplots(2, 2, figsize=(8,8))
ax[0, 0].hist(mprf_1_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[0, 0].hist(mprf_1_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[0, 0].set_title('Pool 1')
ax[0, 0].set_xlabel('Mutations per Read')
ax[0, 0].set_ylabel('Count')
ax[0, 0].legend()
ax[0, 1].hist(mprf_2_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[0, 1].hist(mprf_2_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[0, 1].set_title('Pool 2')
ax[0, 1].set_xlabel('Mutations per Read')
ax[0, 1].set_ylabel('Count')
ax[0, 1].legend()
ax[1, 0].hist(mprf_3_bound, bins=10, color='blue', alpha=0.5, label='Bound')
ax[1, 0].hist(mprf_3_unbound, bins=10, color='red', alpha=0.5, label='Unbound')
ax[1, 0].set_title('Pool 3')
ax[1, 0].set_xlabel('Mutations per Read')
ax[1, 0].set_ylabel('Count')
ax[1, 0].legend()

plt.tight_layout()

# %%
# read in .txt files, values separated by whitespace
mpr_1_1_bound = np.loadtxt(second_round_dir + '1_1_mpr_bound.txt')
mpr_1_1_unbound = np.loadtxt(second_round_dir + '1_1_mpr_unbound.txt')
mpr_1_2_bound = np.loadtxt(second_round_dir + '1_2_mpr_bound.txt')
mpr_1_2_unbound = np.loadtxt(second_round_dir + '1_2_mpr_unbound.txt')
mpr_1_3_bound = np.loadtxt(second_round_dir + '1_3_mpr_bound.txt')
mpr_1_3_unbound = np.loadtxt(second_round_dir + '1_3_mpr_unbound.txt')
mpr_1_4_bound = np.loadtxt(second_round_dir + '1_4_mpr_bound.txt')
mpr_1_4_unbound = np.loadtxt(second_round_dir + '1_4_mpr_unbound.txt')
mpr_2_1_bound = np.loadtxt(second_round_dir + '2_1_mpr_bound.txt')
mpr_2_1_unbound = np.loadtxt(second_round_dir + '2_1_mpr_unbound.txt')
mpr_2_2_bound = np.loadtxt(second_round_dir + '2_2_mpr_bound.txt')
mpr_2_2_unbound = np.loadtxt(second_round_dir + '2_2_mpr_unbound.txt')
mpr_2_3_bound = np.loadtxt(second_round_dir + '2_3_mpr_bound.txt')
mpr_2_3_unbound = np.loadtxt(second_round_dir + '2_3_mpr_unbound.txt')
mpr_2_4_bound = np.loadtxt(second_round_dir + '2_4_mpr_bound.txt')
mpr_2_4_unbound = np.loadtxt(second_round_dir + '2_4_mpr_unbound.txt')
mpr_3_1_bound = np.loadtxt(second_round_dir + '3_1_mpr_bound.txt')
mpr_3_1_unbound = np.loadtxt(second_round_dir + '3_1_mpr_unbound.txt')
mpr_3_2_bound = np.loadtxt(second_round_dir + '3_2_mpr_bound.txt')
mpr_3_2_unbound = np.loadtxt(second_round_dir + '3_2_mpr_unbound.txt')
mpr_3_3_bound = np.loadtxt(second_round_dir + '3_3_mpr_bound.txt')
mpr_3_3_unbound = np.loadtxt(second_round_dir + '3_3_mpr_unbound.txt')
mpr_3_4_bound = np.loadtxt(second_round_dir + '3_4_mpr_bound.txt')
mpr_3_4_unbound = np.loadtxt(second_round_dir + '3_4_mpr_unbound.txt')
mpr_4_1_bound = np.loadtxt(second_round_dir + '4_1_mpr_bound.txt')
mpr_4_1_unbound = np.loadtxt(second_round_dir + '4_1_mpr_unbound.txt')
mpr_4_2_bound = np.loadtxt(second_round_dir + '4_2_mpr_bound.txt')
mpr_4_2_unbound = np.loadtxt(second_round_dir + '4_2_mpr_unbound.txt')
mpr_4_3_bound = np.loadtxt(second_round_dir + '4_3_mpr_bound.txt')
mpr_4_3_unbound = np.loadtxt(second_round_dir + '4_3_mpr_unbound.txt')
mpr_4_4_bound = np.loadtxt(second_round_dir + '4_4_mpr_bound.txt')
mpr_4_4_unbound = np.loadtxt(second_round_dir + '4_4_mpr_unbound.txt')


mprf_1_1_bound = np.loadtxt(second_round_dir + '1_1_mprf_bound.txt')
mprf_1_1_unbound = np.loadtxt(second_round_dir + '1_1_mprf_unbound.txt')
mprf_1_2_bound = np.loadtxt(second_round_dir + '1_2_mprf_bound.txt')
mprf_1_2_unbound = np.loadtxt(second_round_dir + '1_2_mprf_unbound.txt')
mprf_1_3_bound = np.loadtxt(second_round_dir + '1_3_mprf_bound.txt')
mprf_1_3_unbound = np.loadtxt(second_round_dir + '1_3_mprf_unbound.txt')
mprf_1_4_bound = np.loadtxt(second_round_dir + '1_4_mprf_bound.txt')
mprf_1_4_unbound = np.loadtxt(second_round_dir + '1_4_mprf_unbound.txt')
mprf_2_1_bound = np.loadtxt(second_round_dir + '2_1_mprf_bound.txt')
mprf_2_1_unbound = np.loadtxt(second_round_dir + '2_1_mprf_unbound.txt')
mprf_2_2_bound = np.loadtxt(second_round_dir + '2_2_mprf_bound.txt')
mprf_2_2_unbound = np.loadtxt(second_round_dir + '2_2_mprf_unbound.txt')
mprf_2_3_bound = np.loadtxt(second_round_dir + '2_3_mprf_bound.txt')
mprf_2_3_unbound = np.loadtxt(second_round_dir + '2_3_mprf_unbound.txt')
mprf_2_4_bound = np.loadtxt(second_round_dir + '2_4_mprf_bound.txt')
mprf_2_4_unbound = np.loadtxt(second_round_dir + '2_4_mprf_unbound.txt')
mprf_3_1_bound = np.loadtxt(second_round_dir + '3_1_mprf_bound.txt')
mprf_3_1_unbound = np.loadtxt(second_round_dir + '3_1_mprf_unbound.txt')
mprf_3_2_bound = np.loadtxt(second_round_dir + '3_2_mprf_bound.txt')
mprf_3_2_unbound = np.loadtxt(second_round_dir + '3_2_mprf_unbound.txt')
mprf_3_3_bound = np.loadtxt(second_round_dir + '3_3_mprf_bound.txt')
mprf_3_3_unbound = np.loadtxt(second_round_dir + '3_3_mprf_unbound.txt')
mprf_3_4_bound = np.loadtxt(second_round_dir + '3_4_mprf_bound.txt')
mprf_3_4_unbound = np.loadtxt(second_round_dir + '3_4_mprf_unbound.txt')
mprf_4_1_bound = np.loadtxt(second_round_dir + '4_1_mprf_bound.txt')
mprf_4_1_unbound = np.loadtxt(second_round_dir + '4_1_mprf_unbound.txt')
mprf_4_2_bound = np.loadtxt(second_round_dir + '4_2_mprf_bound.txt')
mprf_4_2_unbound = np.loadtxt(second_round_dir + '4_2_mprf_unbound.txt')
mprf_4_3_bound = np.loadtxt(second_round_dir + '4_3_mprf_bound.txt')
mprf_4_3_unbound = np.loadtxt(second_round_dir + '4_3_mprf_unbound.txt')
mprf_4_4_bound = np.loadtxt(second_round_dir + '4_4_mprf_bound.txt')
mprf_4_4_unbound = np.loadtxt(second_round_dir + '4_4_mprf_unbound.txt')

rl_1_1 = np.loadtxt(second_round_dir + '1_1_read_lengths.txt')
rl_1_2 = np.loadtxt(second_round_dir + '1_2_read_lengths.txt')
rl_1_3 = np.loadtxt(second_round_dir + '1_3_read_lengths.txt')
rl_1_4 = np.loadtxt(second_round_dir + '1_4_read_lengths.txt')
rl_2_1 = np.loadtxt(second_round_dir + '2_1_read_lengths.txt')
rl_2_2 = np.loadtxt(second_round_dir + '2_2_read_lengths.txt')
rl_2_3 = np.loadtxt(second_round_dir + '2_3_read_lengths.txt')
rl_2_4 = np.loadtxt(second_round_dir + '2_4_read_lengths.txt')
rl_3_1 = np.loadtxt(second_round_dir + '3_1_read_lengths.txt')
rl_3_2 = np.loadtxt(second_round_dir + '3_2_read_lengths.txt')
rl_3_3 = np.loadtxt(second_round_dir + '3_3_read_lengths.txt')
rl_3_4 = np.loadtxt(second_round_dir + '3_4_read_lengths.txt')
rl_4_1 = np.loadtxt(second_round_dir + '4_1_read_lengths.txt')
rl_4_2 = np.loadtxt(second_round_dir + '4_2_read_lengths.txt')
rl_4_3 = np.loadtxt(second_round_dir + '4_3_read_lengths.txt')
rl_4_4 = np.loadtxt(second_round_dir + '4_4_read_lengths.txt')

# %%
# Table with number of reads bound, unbound, and total for each pool
table = np.zeros((16, 3))
table[0, 0] = np.sum(mprf_1_1_bound)
table[0, 1] = np.sum(mprf_1_1_unbound)
table[0, 2] = table[0, 0] + table[0, 1]
table[1, 0] = np.sum(mprf_1_2_bound)
table[1, 1] = np.sum(mprf_1_2_unbound)
table[1, 2] = table[1, 0] + table[1, 1]
table[2, 0] = np.sum(mprf_1_3_bound)
table[2, 1] = np.sum(mprf_1_3_unbound)
table[2, 2] = table[2, 0] + table[2, 1]
table[3, 0] = np.sum(mprf_1_4_bound)
table[3, 1] = np.sum(mprf_1_4_unbound)
table[3, 2] = table[3, 0] + table[3, 1]
table[4, 0] = np.sum(mprf_2_1_bound)
table[4, 1] = np.sum(mprf_2_1_unbound)
table[4, 2] = table[4, 0] + table[4, 1]
table[5, 0] = np.sum(mprf_2_2_bound)
table[5, 1] = np.sum(mprf_2_2_unbound)
table[5, 2] = table[5, 0] + table[5, 1]
table[6, 0] = np.sum(mprf_2_3_bound)
table[6, 1] = np.sum(mprf_2_3_unbound)
table[6, 2] = table[6, 0] + table[6, 1]
table[7, 0] = np.sum(mprf_2_4_bound)
table[7, 1] = np.sum(mprf_2_4_unbound)
table[7, 2] = table[7, 0] + table[7, 1]
table[8, 0] = np.sum(mprf_3_1_bound)
table[8, 1] = np.sum(mprf_3_1_unbound)
table[8, 2] = table[8, 0] + table[8, 1]
table[9, 0] = np.sum(mprf_3_2_bound)
table[9, 1] = np.sum(mprf_3_2_unbound)
table[9, 2] = table[9, 0] + table[9, 1]
table[10, 0] = np.sum(mprf_3_3_bound)
table[10, 1] = np.sum(mprf_3_3_unbound)
table[10, 2] = table[10, 0] + table[10, 1]
table[11, 0] = np.sum(mprf_3_4_bound)
table[11, 1] = np.sum(mprf_3_4_unbound)
table[11, 2] = table[11, 0] + table[11, 1]
table[12, 0] = np.sum(mprf_4_1_bound)
table[12, 1] = np.sum(mprf_4_1_unbound)
table[12, 2] = table[12, 0] + table[12, 1]
table[13, 0] = np.sum(mprf_4_2_bound)
table[13, 1] = np.sum(mprf_4_2_unbound)
table[13, 2] = table[13, 0] + table[13, 1]
table[14, 0] = np.sum(mprf_4_3_bound)
table[14, 1] = np.sum(mprf_4_3_unbound)
table[14, 2] = table[14, 0] + table[14, 1]
table[15, 0] = np.sum(mprf_4_4_bound)
table[15, 1] = np.sum(mprf_4_4_unbound)
table[15, 2] = table[15, 0] + table[15, 1]

# convert to integers
table = table.astype(int)

# name rows and columns
rows = ['1_1', '1_2', '1_3', '1_4', '2_1', '2_2', '2_3', '2_4', '3_1', '3_2', '3_3', '3_4', '4_1', '4_2', '4_3', '4_4']
columns = ['pool', 'bound', 'unbound', 'total']

# print table
print(tabulate(table, headers=columns, showindex=rows, tablefmt='pretty'))
# Out:
# +------+---------+---------+---------+
# | pool |  bound  | unbound |  total  |
# +------+---------+---------+---------+
# | 1_1  | 1579053 | 1009002 | 2588055 |
# | 1_2  | 1319489 | 1383705 | 2703194 |
# | 1_3  | 1438523 | 1479698 | 2918221 |
# | 1_4  | 1110004 | 1316715 | 2426719 |
# | 2_1  | 1676974 | 1332670 | 3009644 |
# | 2_2  | 1970998 | 1077391 | 3048389 |
# | 2_3  | 1722006 | 1346485 | 3068491 |
# | 2_4  | 1688216 | 1308305 | 2996521 |
# | 3_1  | 1353297 | 1732750 | 3086047 |
# | 3_2  | 973072  | 1134651 | 2107723 |
# | 3_3  |  74409  | 1295246 | 1369655 |
# | 3_4  | 1633411 | 131647  | 1765058 |
# | 4_1  | 2278637 | 903754  | 3182391 |
# | 4_2  | 1415395 | 991270  | 2406665 |
# | 4_3  | 823620  | 1207748 | 2031368 |
# | 4_4  | 1085168 | 893491  | 1978659 |
# +------+---------+---------+---------+

# %%
# Table with number of reads bound, unbound, and total for each pool
table = np.zeros((16, 3))
table[0, 0] = np.sum(mpr_1_1_bound)
table[0, 1] = np.sum(mpr_1_1_unbound)
table[0, 2] = table[0, 0] + table[0, 1]
table[1, 0] = np.sum(mpr_1_2_bound)
table[1, 1] = np.sum(mpr_1_2_unbound)
table[1, 2] = table[1, 0] + table[1, 1]
table[2, 0] = np.sum(mpr_1_3_bound)
table[2, 1] = np.sum(mpr_1_3_unbound)
table[2, 2] = table[2, 0] + table[2, 1]
table[3, 0] = np.sum(mpr_1_4_bound)
table[3, 1] = np.sum(mpr_1_4_unbound)
table[3, 2] = table[3, 0] + table[3, 1]
table[4, 0] = np.sum(mpr_2_1_bound)
table[4, 1] = np.sum(mpr_2_1_unbound)
table[4, 2] = table[4, 0] + table[4, 1]
table[5, 0] = np.sum(mpr_2_2_bound)
table[5, 1] = np.sum(mpr_2_2_unbound)
table[5, 2] = table[5, 0] + table[5, 1]
table[6, 0] = np.sum(mpr_2_3_bound)
table[6, 1] = np.sum(mpr_2_3_unbound)
table[6, 2] = table[6, 0] + table[6, 1]
table[7, 0] = np.sum(mpr_2_4_bound)
table[7, 1] = np.sum(mpr_2_4_unbound)
table[7, 2] = table[7, 0] + table[7, 1]
table[8, 0] = np.sum(mpr_3_1_bound)
table[8, 1] = np.sum(mpr_3_1_unbound)
table[8, 2] = table[8, 0] + table[8, 1]
table[9, 0] = np.sum(mpr_3_2_bound)
table[9, 1] = np.sum(mpr_3_2_unbound)
table[9, 2] = table[9, 0] + table[9, 1]
table[10, 0] = np.sum(mpr_3_3_bound)
table[10, 1] = np.sum(mpr_3_3_unbound)
table[10, 2] = table[10, 0] + table[10, 1]
table[11, 0] = np.sum(mpr_3_4_bound)
table[11, 1] = np.sum(mpr_3_4_unbound)
table[11, 2] = table[11, 0] + table[11, 1]
table[12, 0] = np.sum(mpr_4_1_bound)
table[12, 1] = np.sum(mpr_4_1_unbound)
table[12, 2] = table[12, 0] + table[12, 1]
table[13, 0] = np.sum(mpr_4_2_bound)
table[13, 1] = np.sum(mpr_4_2_unbound)
table[13, 2] = table[13, 0] + table[13, 1]
table[14, 0] = np.sum(mpr_4_3_bound)
table[14, 1] = np.sum(mpr_4_3_unbound)
table[14, 2] = table[14, 0] + table[14, 1]
table[15, 0] = np.sum(mpr_4_4_bound)
table[15, 1] = np.sum(mpr_4_4_unbound)
table[15, 2] = table[15, 0] + table[15, 1]

# convert to integers
table = table.astype(int)

# name rows and columns
rows = ['1_1', '1_2', '1_3', '1_4', '2_1', '2_2', '2_3', '2_4', '3_1', '3_2', '3_3', '3_4', '4_1', '4_2', '4_3', '4_4']
columns = ['pool', 'bound', 'unbound', 'total']

# print table
print(tabulate(table, headers=columns, showindex=rows, tablefmt='pretty'))
# Out:
# +------+---------+---------+---------+
# | pool |  bound  | unbound |  total  |
# +------+---------+---------+---------+
# | 1_1  | 1860258 | 1178050 | 3038308 |
# | 1_2  | 1541539 | 1609008 | 3150547 |
# | 1_3  | 1673375 | 1726956 | 3400331 |
# | 1_4  | 1290050 | 1539773 | 2829823 |
# | 2_1  | 2034549 | 1579738 | 3614287 |
# | 2_2  | 2346321 | 1250815 | 3597136 |
# | 2_3  | 2050480 | 1602080 | 3652560 |
# | 2_4  | 1994911 | 1617603 | 3612514 |
# | 3_1  | 1584235 | 2027677 | 3611912 |
# | 3_2  | 1137210 | 1359720 | 2496930 |
# | 3_3  | 121219  | 1523687 | 1644906 |
# | 3_4  | 1898957 | 157113  | 2056070 |
# | 4_1  | 2592768 | 1024407 | 3617175 |
# | 4_2  | 1631856 | 1126206 | 2758062 |
# | 4_3  | 933446  | 1374310 | 2307756 |
# | 4_4  | 1238953 | 1015894 | 2254847 |
# +------+---------+---------+---------+

# %%
# plot histograms of read lengths
# color the bins < 30 black

fig, ax = plt.subplots(4, 4, figsize=(8,8))
ax[0, 0].hist(rl_1_1, bins=100, color='blue', alpha=.5)
ax[0, 0].set_title('Pool 1 1')
ax[0, 0].axvline(x=100, color='black')
ax[0, 1].hist(rl_1_2, bins=100, color='blue', alpha=.5)
ax[0, 1].set_title('Pool 1 2')
ax[0, 1].axvline(x=100, color='black')
ax[0, 2].hist(rl_1_3, bins=100, color='blue', alpha=.5)
ax[0, 2].set_title('Pool 1 3')
ax[0, 2].axvline(x=100, color='black')
ax[0, 3].hist(rl_1_4, bins=100, color='blue', alpha=.5)
ax[0, 3].set_title('Pool 1 4')
ax[0, 3].axvline(x=100, color='black')
ax[1, 0].hist(rl_2_1, bins=100, color='blue', alpha=.5)
ax[1, 0].set_title('Pool 2 1')
ax[1, 0].axvline(x=100, color='black')
ax[1, 1].hist(rl_2_2, bins=100, color='blue', alpha=.5)
ax[1, 1].set_title('Pool 2 2')
ax[1, 1].axvline(x=100, color='black')
ax[1, 2].hist(rl_2_3, bins=100, color='blue', alpha=.5)
ax[1, 2].set_title('Pool 2 3')
ax[1, 2].axvline(x=100, color='black')
ax[1, 3].hist(rl_2_4, bins=100, color='blue', alpha=.5)
ax[1, 3].set_title('Pool 2 4')
ax[1, 3].axvline(x=100, color='black')
ax[2, 0].hist(rl_3_1, bins=100, color='blue', alpha=.5)
ax[2, 0].set_title('Pool 3 1')
ax[2, 0].axvline(x=100, color='black')
ax[2, 1].hist(rl_3_2, bins=100, color='blue', alpha=.5)
ax[2, 1].set_title('Pool 3 2')
ax[2, 1].axvline(x=100, color='black')
ax[2, 2].hist(rl_3_3, bins=100, color='blue', alpha=.5)
ax[2, 2].set_title('Pool 3 3')
ax[2, 2].axvline(x=100, color='black')
ax[2, 3].hist(rl_3_4, bins=100, color='blue', alpha=.5)
ax[2, 3].set_title('Pool 3 4')
ax[2, 3].axvline(x=100, color='black')
ax[3, 0].hist(rl_4_1, bins=100, color='blue', alpha=.5)
ax[3, 0].set_title('Pool 4 1')
ax[3, 0].axvline(x=100, color='black')
ax[3, 1].hist(rl_4_2, bins=100, color='blue', alpha=.5)
ax[3, 1].set_title('Pool 4 2')
ax[3, 1].axvline(x=100, color='black')
ax[3, 2].hist(rl_4_3, bins=100, color='blue', alpha=.5)
ax[3, 2].set_title('Pool 4 3')
ax[3, 2].axvline(x=100, color='black')
ax[3, 3].hist(rl_4_4, bins=100, color='blue', alpha=.5)
ax[3, 3].set_title('Pool 4 4')
ax[3, 3].axvline(x=100, color='black')

# set title of figure
fig.suptitle('Histogram of read lengths', fontsize=16)

plt.tight_layout()

# %%
# plot histograms of mutations per read bound vs unbound
fig, ax = plt.subplots(4, 4, figsize=(8,8))
ax[0, 0].hist(mpr_1_1_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[0, 0].hist(mpr_1_1_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
# vertical line at 6 mutations
ax[0, 0].axvline(x=6, color='black')
ax[0, 0].set_title('Pool 1 1')
ax[0, 1].hist(mpr_1_2_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[0, 1].hist(mpr_1_2_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[0, 1].axvline(x=6, color='black')
ax[0, 1].set_title('Pool 1 2')
ax[0, 2].hist(mpr_1_3_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[0, 2].hist(mpr_1_3_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[0, 2].axvline(x=6, color='black')
ax[0, 2].set_title('Pool 1 3')
ax[0, 3].hist(mpr_1_4_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[0, 3].hist(mpr_1_4_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[0, 3].axvline(x=6, color='black')
ax[0, 3].set_title('Pool 1 4')
ax[1, 0].hist(mpr_2_1_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[1, 0].hist(mpr_2_1_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[1, 0].axvline(x=6, color='black')
ax[1, 0].set_title('Pool 2 1')
ax[1, 1].hist(mpr_2_2_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[1, 1].hist(mpr_2_2_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[1, 1].axvline(x=6, color='black')
ax[1, 1].set_title('Pool 2 2')
ax[1, 2].hist(mpr_2_3_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[1, 2].hist(mpr_2_3_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[1, 2].axvline(x=6, color='black')
ax[1, 2].set_title('Pool 2 3')
ax[1, 3].hist(mpr_2_4_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[1, 3].hist(mpr_2_4_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[1, 3].axvline(x=6, color='black')
ax[1, 3].set_title('Pool 2 4')
ax[2, 0].hist(mpr_3_1_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[2, 0].hist(mpr_3_1_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[2, 0].axvline(x=6, color='black')
ax[2, 0].set_title('Pool 3 1')
ax[2, 1].hist(mpr_3_2_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[2, 1].hist(mpr_3_2_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[2, 1].axvline(x=6, color='black')
ax[2, 1].set_title('Pool 3 2')
ax[2, 2].hist(mpr_3_3_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[2, 2].hist(mpr_3_3_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[2, 2].axvline(x=6, color='black')
ax[2, 2].set_title('Pool 3 3')
ax[2, 3].hist(mpr_3_4_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[2, 3].hist(mpr_3_4_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[2, 3].axvline(x=6, color='black')
ax[2, 3].set_title('Pool 3 4')
ax[3, 0].hist(mpr_4_1_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[3, 0].hist(mpr_4_1_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[3, 0].axvline(x=6, color='black')
ax[3, 0].set_title('Pool 4 1')
ax[3, 1].hist(mpr_4_2_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[3, 1].hist(mpr_4_2_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[3, 1].axvline(x=6, color='black')
ax[3, 1].set_title('Pool 4 2')
ax[3, 2].hist(mpr_4_3_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[3, 2].hist(mpr_4_3_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[3, 2].axvline(x=6, color='black')
ax[3, 2].set_title('Pool 4 3')
ax[3, 3].hist(mpr_4_4_bound, bins=11, color='blue', alpha=0.5, label='Bound')
ax[3, 3].hist(mpr_4_4_unbound, bins=11, color='red', alpha=0.5, label='Unbound')
ax[3, 3].axvline(x=6, color='black')
ax[3, 3].set_title('Pool 4 4')
# add single legend next to title
ax[0,3].legend(loc='upper right', bbox_to_anchor=(1.5, 1.5), ncol=2)
# set title of figure
fig.suptitle('Histogram of Mutations per read (before filtering)', fontsize=16)

plt.tight_layout()

# %%
# plot histograms of mutations per read bound vs unbound
fig, ax = plt.subplots(4, 4, figsize=(8,8))
ax[0, 0].hist(mprf_1_1_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[0, 0].hist(mprf_1_1_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[0, 0].set_title('Pool 1 1')
ax[0, 1].hist(mprf_1_2_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[0, 1].hist(mprf_1_2_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[0, 1].set_title('Pool 1 2')
ax[0, 2].hist(mprf_1_3_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[0, 2].hist(mprf_1_3_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[0, 2].set_title('Pool 1 3')
ax[0, 3].hist(mprf_1_4_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[0, 3].hist(mprf_1_4_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[0, 3].set_title('Pool 1 4')
ax[1, 0].hist(mprf_2_1_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[1, 0].hist(mprf_2_1_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[1, 0].set_title('Pool 2 1')
ax[1, 1].hist(mprf_2_2_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[1, 1].hist(mprf_2_2_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[1, 1].set_title('Pool 2 2')
ax[1, 2].hist(mprf_2_3_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[1, 2].hist(mprf_2_3_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[1, 2].set_title('Pool 2 3')
ax[1, 3].hist(mprf_2_4_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[1, 3].hist(mprf_2_4_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[1, 3].set_title('Pool 2 4')
ax[2, 0].hist(mprf_3_1_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[2, 0].hist(mprf_3_1_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[2, 0].set_title('Pool 3 1')
ax[2, 1].hist(mprf_3_2_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[2, 1].hist(mprf_3_2_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[2, 1].set_title('Pool 3 2')
ax[2, 2].hist(mprf_3_3_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[2, 2].hist(mprf_3_3_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[2, 2].set_title('Pool 3 3')
ax[2, 3].hist(mprf_3_4_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[2, 3].hist(mprf_3_4_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[2, 3].set_title('Pool 3 4')
ax[3, 0].hist(mprf_4_1_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[3, 0].hist(mprf_4_1_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[3, 0].set_title('Pool 4 1')
ax[3, 1].hist(mprf_4_2_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[3, 1].hist(mprf_4_2_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[3, 1].set_title('Pool 4 2')
ax[3, 2].hist(mprf_4_3_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[3, 2].hist(mprf_4_3_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[3, 2].set_title('Pool 4 3')
ax[3, 3].hist(mprf_4_4_bound, bins=6, color='blue', alpha=0.5, label='Bound')
ax[3, 3].hist(mprf_4_4_unbound, bins=6, color='red', alpha=0.5, label='Unbound')
ax[3, 3].set_title('Pool 4 4')
# add single legend next to title
ax[0,3].legend(loc='upper right', bbox_to_anchor=(1.5, 1.5), ncol=2)

# set title of figure
fig.suptitle('Histogram of Mutations per read (after filtering)', fontsize=16)

plt.tight_layout()

# %%
#set path to simulation data
simulation_path = "../data/simulation_data/experimental_conditions_2"

# %%
# read in kd values
single_kd_sim = np.loadtxt(simulation_path+'/secondFromProt1/prot1/single_kds.txt')

# %%
# plot hist of simulated kd values
plt.hist(single_kd_sim, bins=10, color='blue', alpha=0.5, label='Simulated Kd Values')
# Out:
# (array([258.,  23.,   9.,   3.,   4.,   0.,   2.,   0.,   0.,   1.]),
#  array([ 0.111842 ,  1.6521978,  3.1925536,  4.7329094,  6.2732652,
#          7.813621 ,  9.3539768, 10.8943326, 12.4346884, 13.9750442,
#         15.5154   ]),
#  <BarContainer object of 10 artists>)

# %%
# lineplot of simulated kd values
plt.plot(single_kd_sim, color='blue', alpha=0.5, label='Simulated Kd Values')
